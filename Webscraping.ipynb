# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://maine.maps.arcgis.com/apps/dashboards/414d5af751e742ecb2e14796d6a1401a'
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
print(res.content)
# Out:
# b'<!DOCTYPE html>\r\n<html>\r\n  <head>\r\n    <meta charset="utf-8" />\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n    <title>ArcGIS Dashboards</title>\r\n    <meta name="description" content="ArcGIS Dashboards" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\r\n    <meta http-equiv="Content-Security-Policy" content="" />\r\n    <link rel="icon" href="assets/images/arcgis-dashboards-16-57c7bdca757e2544acb67f661775b0ba.png" type="image/png" />\r\n\r\n    \n<link href="assets/arcgis-core/themes/dark/main.css" rel="stylesheet" type="text/css" data-theme="api-dark">\n<link href="assets/arcgis-core/themes/light/main.css" rel="stylesheet" type="text/css" data-theme="api-light">\r\n    <link rel="stylesheet" href="assets/vendor-2b39fb725719f7dbda5c70713940b9f6.css" />\r\n    <link rel="stylesheet" href="assets/app-3b56db0b8be782feb677676e31752c83.css" />\r\n    <script src="assets/before-amd-c876bbabc07a117e73a6b5e74c4dd779.js"></script>\r\n  </head>\r\n\r\n  <body>\r\n    <div id="initialLoadingContainer" class="loader-icon-container">\r\n      <calcite-loader scale="l"></calcite-loader>\r\n    </div>\r\n\r\n    \r\n    <script src="assets/vendor-813539df8720a4021ae0e4004e55d869.js"></script>\n<script src="assets/chunk.58222.523c379d3e2a7d5d8e33.js"></script>\n<script src="assets/chunk.32143.0d0479a47c92458aa905.js"></script>\r\n    <script src="assets/nickel-edaaf1d199728132b7bf2077d3accc40.js"></script>\r\n    \r\n  </body>\r\n</html>\r\n'

# %%
soup = BeautifulSoup(res.content)

# %%
url = 'https://maine.maps.arcgis.com/apps/dashboards/414d5af751e742ecb2e14796d6a1401a'
res = requests.get(url)
soup = BeautifulSoup(res.content, 'html.parser')

# Find tables on the page
tables = soup.find_all('table')

# Loop through tables and print their content
for table in tables:
    print("Table:")
    for row in table.find_all('tr'):
        columns = row.find_all(['th', 'td'])
        for col in columns:
            print(col.get_text(strip=True), end='\t')
        print()
    print("\n" + "="*50 + "\n")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>ArcGIS Dashboards</title>
# <meta content="ArcGIS Dashboards" name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="" http-equiv="Content-Security-Policy"/>
# <link href="assets/images/arcgis-dashboards-16-57c7bdca757e2544acb67f661775b0ba.png" rel="icon" type="image/png"/>
# <link data-theme="api-dark" href="assets/arcgis-core/themes/dark/main.css" rel="stylesheet" type="text/css"/>
# <link data-theme="api-light" href="assets/arcgis-core/themes/light/main.css" rel="stylesheet" type="text/css"/>
# <link href="assets/vendor-2b39fb725719f7dbda5c70713940b9f6.css" rel="stylesheet"/>
# <link href="assets/app-3b56db0b8be782feb677676e31752c83.css" rel="stylesheet"/>
# <script src="assets/before-amd-c876bbabc07a117e73a6b5e74c4dd779.js"></script>
# </head>
# <body>
# <div class="loader-icon-container" id="initialLoadingContainer">
# <calcite-loader scale="l"></calcite-loader>
# </div>
# <script src="assets/vendor-813539df8720a4021ae0e4004e55d869.js"></script>
# <script src="assets/chunk.58222.523c379d3e2a7d5d8e33.js"></script>
# <script src="assets/chunk.32143.0d0479a47c92458aa905.js"></script>
# <script src="assets/nickel-edaaf1d199728132b7bf2077d3accc40.js"></script>
# </body>
# </html>

# %%
tables

# %%
from selenium import webdriver

# %%
url = 'https://maine.maps.arcgis.com/apps/dashboards/414d5af751e742ecb2e14796d6a1401a'

# Use a web driver (in this case, Chrome) to load the dynamic content
driver = webdriver.Chrome()
driver.get(url)

time.sleep(30)

# %%
# Get the page source after it has been fully loaded
page_source1 = driver.page_source

# %%
#page_source1

# %%
# Close the browser

# Parse the page source with BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Now you can try to find and print tables
# tables = soup.find_all('table')
# for table in tables:
#     print(table)
#     print("\n" + "="*50 + "\n")

# %%
soup

# %%
driver.quit()

# %%
import time

# %%
time.sleep(3)

# %%
# I want to create a loop or loops that will pull the values I need from two tables on the webpage. Only 1 observation is displayed in the table at a time and there are buttons on the dashboard to access the next observation. 



#On the dashboard I would need to select a date range in this piece:
<span class="text-ellipsis" title="Select Date or Date Range">\n      Select Date or Date Range\n    </span>\n  </div>\n    <div class="font-light dashboard-secondary-text-color flex">\n      <span class="text-ellipsis" title="4/1/2021 - 10/31/2022">\n 

# and i would need to select the organization to be this
<span class="text-ellipsis" title="FOCW (Friends of the Cobbossee Watershed)">
        FOCW (Friends of the Cobbossee Watershed)
      </span>

# In the Shift DETAILS Table:
<div class="caption">
        <p style="text-align:center"><span style="color:#004da8"><strong>SHIFT DETAILS</strong></span></p>

      </div>
<p style="text-align:center"><span style="color:#004da8"><strong>SHIFT DETAILS</strong></span></p>
<strong>SHIFT DETAILS</strong>

# From here:
<table class="esri-widget__table" summary="List of attributes and values"><tbody><tr><th class="esri-feature-fields__field-header">AGENCY</th><td class="esri-feature-fields__field-data">Friends of the Cobbossee Watershed (FOCW)</td></tr><tr><th class="esri-feature-fields__field-header">SITE_NAME</th><td class="esri-feature-fields__field-data">East Winthrop Cobbosseecontee</td></tr><tr><th class="esri-feature-fields__field-header">DATE</th><td class="esri-feature-fields__field-data">09/25/2022</td></tr><tr><th class="esri-feature-fields__field-header">DATE1</th><td class="esri-feature-fields__field-data esri-feature-fields__field-data--date">September 25, 2022</td></tr><tr><th class="esri-feature-fields__field-header">DAY</th><td class="esri-feature-fields__field-data">Sun</td></tr><tr><th class="esri-feature-fields__field-header">INSPECTOR_ID</th><td class="esri-feature-fields__field-data">5648</td></tr><tr><th class="esri-feature-fields__field-header">PAY_VOL</th><td class="esri-feature-fields__field-data">Paid</td></tr><tr><th class="esri-feature-fields__field-header">START_SHIFT</th><td class="esri-feature-fields__field-data">07:00</td></tr><tr><th class="esri-feature-fields__field-header">END_SHIFT</th><td class="esri-feature-fields__field-data">17:00</td></tr><tr><th class="esri-feature-fields__field-header">INSPECTIONS</th><td class="esri-feature-fields__field-data">Yes</td></tr><tr><th class="esri-feature-fields__field-header">TOTALINSP</th><td class="esri-feature-fields__field-data">17</td></tr><tr><th class="esri-feature-fields__field-header">NUMINVASIVE</th><td class="esri-feature-fields__field-data">0</td></tr></tbody></table>

<th class="esri-feature-fields__field-header">AGENCY</th>
<td class="esri-feature-fields__field-data">Friends of the Cobbossee Watershed (FOCW)</td>


# I need to create a loop that will retrieve the following information:

site_name: <th class="esri-feature-fields__field-header">SITE_NAME</th>
date: <th class="esri-feature-fields__field-header">DATE</th>
day: <th class="esri-feature-fields__field-header">DAY</th>
inspector_id: <th class="esri-feature-fields__field-header">INSPECTOR_ID</th>
paid: <th class="esri-feature-fields__field-header">PAY_VOL</th>
start_shift: <th class="esri-feature-fields__field-header">START_SHIFT</th>
end_shift: <th class="esri-feature-fields__field-header">END_SHIFT</th>
inspections: <th class="esri-feature-fields__field-header">INSPECTIONS</th>
total_insp: <th class="esri-feature-fields__field-header">TOTALINSP</th>
numinvasive: <th class="esri-feature-fields__field-header">NUMINVASIVE</th>

# And store it in a dictionary

item = {'SITE_NAME': site_name, 'DATE1': date, 'DAY': day, 'START_SHIFT': start_shift, 'END_SHIFT': end_shift, 'INSPECTOR_ID': inspector_id, 'PAID': paid, 'TOTALINSP': total_insp, 'NUMINVASIVE': numinvasive}
# Out:
#   File <tokenize>:7
#     </span>
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# This method didn't work

def extract_data_from_row(row):
    headers = ['SITE_NAME', 'DATE', 'DAY', 'INSPECTOR_ID', 'PAY_VOL', 'START_SHIFT', 'END_SHIFT', 'INSPECTIONS', 'TOTALINSP', 'NUMINVASIVE']
    data = {}
    for header in headers:
        th_tag = row.find('th', text=header)
        td_tag = row.find('td', {'class': f'esri-feature-fields__field-data esri-feature-fields__field-data--{header.lower()}'})
        data[header.lower()] = td_tag.text.strip() if td_tag else None
    return data

def scrape_page(url, date_range, organization):
    # Set up Chrome WebDriver
    driver = webdriver.Chrome()
    driver.get(url)

    try:
        # Interaction: Select date range
        date_range_element = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.XPATH, '//span[text()="Select Date or Date Range"]'))
        )
        date_range_element.click()
        
        # Assuming there's an input field for the start and end date, fill them out
        start_date_input = driver.find_element(By.NAME, 'start_date_input')  # Replace with the actual name or identifier
        start_date_input.clear()
        start_date_input.send_keys(start_date)
        
        end_date_input = driver.find_element(By.NAME, 'end_date_input')  # Replace with the actual name or identifier
        end_date_input.clear()
        end_date_input.send_keys(end_date)

        # Interaction: Select organization
        organization_element = driver.find_element(By.XPATH, f'//span[text()="{organization}"]')
        organization_element.click()

        # # Assuming there's a button to submit the form, click it
        # submit_button = driver.find_element(By.XPATH, '//button[text()="Submit"]')  # Replace with the actual text or identifier
        # submit_button.click()

        # Wait for the page to load after the interactions
        time.sleep(5)  # Adjust the sleep time based on your page's loading time

        # Extract data from the table
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        table = soup.find('table', {'class': 'esri-widget__table'})
        if not table:
            print("Table not found.")
            return

        rows = table.find_all('th')
        for row in rows:
            data = extract_data_from_row(row)
            if data:
                print(data)

    finally:
        # Close the browser
        driver.quit()

# %%
url = 'your_url_here'
date_range = "4/1/2021 - 10/31/2022"
organization = "FOCW (Friends of the Cobbossee Watershed)"


scrape_page(url, start_date, end_date, organization)

# %%
# From Tim

url =
driver.get(url)
time.sleep(10)

td class

# %%
from selenium.webdriver.common.by import By

# %%
# This method also didn't work

driver = webdriver.Chrome()
driver.get(url)
time.sleep(10)
print("Done sleeping")

# Find the button using CSS selector and click it
btn = driver.find_element('css selector', 'span.text-ellipsis[title="Select Organization"]')
btn.click()

# Sleep to allow time for the next action
time.sleep(10)

# Find the element using CSS selector (assuming it's a table cell with the specified aria-class)
element = driver.find_element(By.XPATH, f'//span[text()="{FOCW}"]')
elemnt.click()

time.sleep(10)
# Out:
# Done sleeping
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 14
#      11 time.sleep(10)
#      13 # Find the element using CSS selector (assuming it's a table cell with the specified aria-class)
# ---> 14 element = driver.find_element(By.XPATH, f'//span[text()="{FOCW}"]')
#      15 elemnt.click()
#      17 time.sleep(10)
#
# NameError: name 'FOCW' is not defined

# %%
# Can also load the page, tell it to wait, click the buttons i need then use the loop to keep clicking buttons

driver = webdriver.Chrome()
driver.get(url)
time.sleep(15)
print("Done sleeping")

# Manually click the date range and org
# Out:
# Done sleeping

# %%
# loop through each page
source = driver.page_source
soup = BeautifulSoup(source)

# %%
#soup

# %%
data = []

# %%
source = driver.page_source
soup = BeautifulSoup(source)

site_name = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='SITE_NAME').find_next('td').text.strip()
date = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DATE').find_next('td').text.strip()
day = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DAY').find_next('td').text.strip()
inspector_id = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTOR_ID').find_next('td').text.strip()
paid = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='PAY_VOL').find_next('td').text.strip()
start_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='START_SHIFT').find_next('td').text.strip()
end_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='END_SHIFT').find_next('td').text.strip()
inspections = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTIONS').find_next('td').text.strip()
total_insp = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='TOTALINSP').find_next('td').text.strip()
numinvasive = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='NUMINVASIVE').find_next('td').text.strip()

# Create a dictionary
item = {
    'SITE_NAME': site_name,
    'DATE': date,
    'DAY': day,
    'INSPECTOR_ID': inspector_id,
    'PAID': paid,
    'START_SHIFT': start_shift,
    'END_SHIFT': end_shift,
    'INSPECTIONS': inspections,
    'TOTALINSP': total_insp,
    'NUMINVASIVE': numinvasive
}

data.append(item)

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (79, 10)

# %%
df.tail()
# Out:
#                   SITE_NAME        DATE  DAY INSPECTOR_ID  PAID START_SHIFT  \
# 74             Launch Drive  08/07/2021  Sat         5105  Paid       07:00
# 75         Wilson Pond Road  08/07/2021  Sat         5386  Paid       13:00
# 76            East Winthrop  08/07/2021  Sat         3504  Paid       07:00
# 77        Whippoorwill Road  08/07/2021  Sat         4771  Paid       13:00
# 78  Augusta West Kampground  08/07/2021  Sat         4769  Paid       14:00
#
#    END_SHIFT INSPECTIONS TOTALINSP NUMINVASIVE
# 74     13:00         Yes        60
# 75     19:00         Yes        14
# 76     17:00         Yes        23
# 77     19:00         Yes        75
# 78     20:00         Yes        12

# %%
# Didn't use this/ didn't work

def extract_data_from_row(row):
    headers = ['SITE_NAME', 'DATE', 'DAY', 'INSPECTOR_ID', 'PAY_VOL', 'START_SHIFT', 'END_SHIFT', 'INSPECTIONS', 'TOTALINSP', 'NUMINVASIVE']
    data = {}
    for header in headers:
        th_tag = row.find('th', text=header)
        td_tag = row.find('td', {'class': f'esri-feature-fields__field-data esri-feature-fields__field-data--{header.lower()}'})
        data[header.lower()] = td_tag.text.strip() if td_tag else None
    return data



# Find the button using CSS selector and click it
btn = driver.find_element('css selector', 'span.text-ellipsis[title="Select Organization"]')
btn.click()

# Sleep to allow time for the next action
time.sleep(10)

# Find the element using CSS selector (assuming it's a table cell with the specified aria-class)
element = driver.find_element(By.XPATH, f'//span[text()="{FOCW}"]')
elemnt.click()

time.sleep(10)

# %%
# Also didn't work
driver = webdriver.Chrome()
driver.get(url)
time.sleep(10)
print("Done sleeping")

# Find the button using CSS selector and click it
btn = driver.find_element('css selector', 'span.text-ellipsis[title="Select Organization"]')
btn.click()

# Sleep to allow time for the next action
time.sleep(10)

# Find the element using CSS selector (assuming it's a table cell with the specified aria-class)
element = driver.find_element(By.XPATH, f'//span[text()="{FOCW}"]')
elemnt.click()

time.sleep(10)

# %%
sites = []

# %%
driver = webdriver.Chrome()
driver.get(url)
time.sleep(15)
print("Done sleeping")

# Manually click the date range and org
# Out:
# Done sleeping

# %%
# Once the window opends, I manually selected Date Range of 4/1/2021 - 8/15/2021 and Organization FOCW
# 490 observations within those filters

time.sleep(2)

#During the 2 sections I active an auto clicker to click the button on the table in the window

# Number of times I want this code to run
num_iterations=490

for _ in range(num_iterations):
    # Your scraping code
    source = driver.page_source
    soup = BeautifulSoup(source, 'html.parser')

    #Retrieve the features I need
    site_name = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='SITE_NAME').find_next('td').text.strip()
    date = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DATE').find_next('td').text.strip()
    day = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DAY').find_next('td').text.strip()
    inspector_id = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTOR_ID').find_next('td').text.strip()
    paid = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='PAY_VOL').find_next('td').text.strip()
    start_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='START_SHIFT').find_next('td').text.strip()
    end_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='END_SHIFT').find_next('td').text.strip()
    inspections = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTIONS').find_next('td').text.strip()
    total_insp = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='TOTALINSP').find_next('td').text.strip()
    numinvasive = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='NUMINVASIVE').find_next('td').text.strip()

    # Create a dictionary of these features
    item = {
        'SITE_NAME': site_name,
        'DATE': date,
        'DAY': day,
        'INSPECTOR_ID': inspector_id,
        'PAID': paid,
        'START_SHIFT': start_shift,
        'END_SHIFT': end_shift,
        'INSPECTIONS': inspections,
        'TOTALINSP': total_insp,
        'NUMINVASIVE': numinvasive
    }
    
    # Append this observation to the list of shifts
    sites.append(item)
    
    # Convert to a dataframe
    sites_df=pd.DataFrame(sites)
    
    # Use a printout to check the progress as the code runs
    print(sites_df.shape)

    # Wait for 3 seconds before the next iteration
    time.sleep(3)

# Print or process the collected data as needed
print(done)
# Out:
# (1, 10)
# (2, 10)
# (3, 10)
# (4, 10)
# (5, 10)
# (6, 10)
# (7, 10)
# (8, 10)
# (9, 10)
# (10, 10)
# (11, 10)
# (12, 10)
# (13, 10)
# (14, 10)
# (15, 10)
# (16, 10)
# (17, 10)
# (18, 10)
# (19, 10)
# (20, 10)
# (21, 10)
# (22, 10)
# (23, 10)
# (24, 10)
# (25, 10)
# (26, 10)
# (27, 10)
# (28, 10)
# (29, 10)
# (30, 10)
# (31, 10)
# (32, 10)
# (33, 10)
# (34, 10)
# (35, 10)
# (36, 10)
# (37, 10)
# (38, 10)
# (39, 10)
# (40, 10)
# (41, 10)
# (42, 10)
# (43, 10)
# (44, 10)
# (45, 10)
# (46, 10)
# (47, 10)
# (48, 10)
# (49, 10)
# (50, 10)
# (51, 10)
# (52, 10)
# (53, 10)
# (54, 10)
# (55, 10)
# (56, 10)
# (57, 10)
# (58, 10)
# (59, 10)
# (60, 10)
# (61, 10)
# (62, 10)
# (63, 10)
# (64, 10)
# (65, 10)
# (66, 10)
# (67, 10)
# (68, 10)
# (69, 10)
# (70, 10)
# (71, 10)
# (72, 10)
# (73, 10)
# (74, 10)
# (75, 10)
# (76, 10)
# (77, 10)
# (78, 10)
# (79, 10)
# (80, 10)
# (81, 10)
# (82, 10)
# (83, 10)
# (84, 10)
# (85, 10)
# (86, 10)
# (87, 10)
# (88, 10)
# (89, 10)
# (90, 10)
# (91, 10)
# (92, 10)
# (93, 10)
# (94, 10)
# (95, 10)
# (96, 10)
# (97, 10)
# (98, 10)
# (99, 10)
# (100, 10)
# (101, 10)
# (102, 10)
# (103, 10)
# (104, 10)
# (105, 10)
# (106, 10)
# (107, 10)
# (108, 10)
# (109, 10)
# (110, 10)
# (111, 10)
# (112, 10)
# (113, 10)
# (114, 10)
# (115, 10)
# (116, 10)
# (117, 10)
# (118, 10)
# (119, 10)
# (120, 10)
# (121, 10)
# (122, 10)
# (123, 10)
# (124, 10)
# (125, 10)
# (126, 10)
# (127, 10)
# (128, 10)
# (129, 10)
# (130, 10)
# (131, 10)
# (132, 10)
# (133, 10)
# (134, 10)
# (135, 10)
# (136, 10)
# (137, 10)
# (138, 10)
# (139, 10)
# (140, 10)
# (141, 10)
# (142, 10)
# (143, 10)
# (144, 10)
# (145, 10)
# (146, 10)
# (147, 10)
# (148, 10)
# (149, 10)
# (150, 10)
# (151, 10)
# (152, 10)
# (153, 10)
# (154, 10)
# (155, 10)
# (156, 10)
# (157, 10)
# (158, 10)
# (159, 10)
# (160, 10)
# (161, 10)
# (162, 10)
# (163, 10)
# (164, 10)
# (165, 10)
# (166, 10)
# (167, 10)
# (168, 10)
# (169, 10)
# (170, 10)
# (171, 10)
# (172, 10)
# (173, 10)
# (174, 10)
# (175, 10)
# (176, 10)
# (177, 10)
# (178, 10)
# (179, 10)
# (180, 10)
# (181, 10)
# (182, 10)
# (183, 10)
# (184, 10)
# (185, 10)
# (186, 10)
# (187, 10)
# (188, 10)
# (189, 10)
# (190, 10)
# (191, 10)
# (192, 10)
# (193, 10)
# (194, 10)
# (195, 10)
# (196, 10)
# (197, 10)
# (198, 10)
# (199, 10)
# (200, 10)
# (201, 10)
# (202, 10)
# (203, 10)
# (204, 10)
# (205, 10)
# (206, 10)
# (207, 10)
# (208, 10)
# (209, 10)
# (210, 10)
# (211, 10)
# (212, 10)
# (213, 10)
# (214, 10)
# (215, 10)
# (216, 10)
# (217, 10)
# (218, 10)
# (219, 10)
# (220, 10)
# (221, 10)
# (222, 10)
# (223, 10)
# (224, 10)
# (225, 10)
# (226, 10)
# (227, 10)
# (228, 10)
# (229, 10)
# (230, 10)
# (231, 10)
# (232, 10)
# (233, 10)
# (234, 10)
# (235, 10)
# (236, 10)
# (237, 10)
# (238, 10)
# (239, 10)
# (240, 10)
# (241, 10)
# (242, 10)
# (243, 10)
# (244, 10)
# (245, 10)
# (246, 10)
# (247, 10)
# (248, 10)
# (249, 10)
# (250, 10)
# (251, 10)
# (252, 10)
# (253, 10)
# (254, 10)
# (255, 10)
# (256, 10)
# (257, 10)
# (258, 10)
# (259, 10)
# (260, 10)
# (261, 10)
# (262, 10)
# (263, 10)
# (264, 10)
# (265, 10)
# (266, 10)
# (267, 10)
# (268, 10)
# (269, 10)
# (270, 10)
# (271, 10)
# (272, 10)
# (273, 10)
# (274, 10)
# (275, 10)
# (276, 10)
# (277, 10)
# (278, 10)
# (279, 10)
# (280, 10)
# (281, 10)
# (282, 10)
# (283, 10)
# (284, 10)
# (285, 10)
# (286, 10)
# (287, 10)
# (288, 10)
# (289, 10)
# (290, 10)
# (291, 10)
# (292, 10)
# (293, 10)
# (294, 10)
# (295, 10)
# (296, 10)
# (297, 10)
# (298, 10)
# (299, 10)
# (300, 10)
# (301, 10)
# (302, 10)
# (303, 10)
# (304, 10)
# (305, 10)
# (306, 10)
# (307, 10)
# (308, 10)
# (309, 10)
# (310, 10)
# (311, 10)
# (312, 10)
# (313, 10)
# (314, 10)
# (315, 10)
# (316, 10)
# (317, 10)
# (318, 10)
# (319, 10)
# (320, 10)
# (321, 10)
# (322, 10)
# (323, 10)
# (324, 10)
# (325, 10)
# (326, 10)
# (327, 10)
# (328, 10)
# (329, 10)
# (330, 10)
# (331, 10)
# (332, 10)
# (333, 10)
# (334, 10)
# (335, 10)
# (336, 10)
# (337, 10)
# (338, 10)
# (339, 10)
# (340, 10)
# (341, 10)
# (342, 10)
# (343, 10)
# (344, 10)
# (345, 10)
# (346, 10)
# (347, 10)
# (348, 10)
# (349, 10)
# (350, 10)
# (351, 10)
# (352, 10)
# (353, 10)
# (354, 10)
# (355, 10)
# (356, 10)
# (357, 10)
# (358, 10)
# (359, 10)
# (360, 10)
# (361, 10)
# (362, 10)
# (363, 10)
# (364, 10)
# (365, 10)
# (366, 10)
# (367, 10)
# (368, 10)
# (369, 10)
# (370, 10)
# (371, 10)
# (372, 10)
# (373, 10)
# (374, 10)
# (375, 10)
# (376, 10)
# (377, 10)
# (378, 10)
# (379, 10)
# (380, 10)
# (381, 10)
# (382, 10)
# (383, 10)
# (384, 10)
# (385, 10)
# (386, 10)
# (387, 10)
# (388, 10)
# (389, 10)
# (390, 10)
# (391, 10)
# (392, 10)
# (393, 10)
# (394, 10)
# (395, 10)
# (396, 10)
# (397, 10)
# (398, 10)
# (399, 10)
# (400, 10)
# (401, 10)
# (402, 10)
# (403, 10)
# (404, 10)
# (405, 10)
# (406, 10)
# (407, 10)
# (408, 10)
# (409, 10)
# (410, 10)
# (411, 10)
# (412, 10)
# (413, 10)
# (414, 10)
# (415, 10)
# (416, 10)
# (417, 10)
# (418, 10)
# (419, 10)
# (420, 10)
# (421, 10)
# (422, 10)
# (423, 10)
# (424, 10)
# (425, 10)
# (426, 10)
# (427, 10)
# (428, 10)
# (429, 10)
# (430, 10)
# (431, 10)
# (432, 10)
# (433, 10)
# (434, 10)
# (435, 10)
# (436, 10)
# (437, 10)
# (438, 10)
# (439, 10)
# (440, 10)
# (441, 10)
# (442, 10)
# (443, 10)
# (444, 10)
# (445, 10)
# (446, 10)
# (447, 10)
# (448, 10)
# (449, 10)
# (450, 10)
# (451, 10)
# (452, 10)
# (453, 10)
# (454, 10)
# (455, 10)
# (456, 10)
# (457, 10)
# (458, 10)
# (459, 10)
# (460, 10)
# (461, 10)
# (462, 10)
# (463, 10)
# (464, 10)
# (465, 10)
# (466, 10)
# (467, 10)
# (468, 10)
# (469, 10)
# (470, 10)
# (471, 10)
# (472, 10)
# (473, 10)
# (474, 10)
# (475, 10)
# (476, 10)
# (477, 10)
# (478, 10)
# (479, 10)
# (480, 10)
# (481, 10)
# (482, 10)
# (483, 10)
# (484, 10)
# (485, 10)
# (486, 10)
# (487, 10)
# (488, 10)
# (489, 10)
# (490, 10)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[163], line 44
#      41     time.sleep(3)
#      43 # Print or process the collected data as needed
# ---> 44 print(done)
#
# NameError: name 'done' is not defined

# %%
sites_df.tail()
# Out:
#                    SITE_NAME        DATE  DAY INSPECTOR_ID  PAID START_SHIFT  \
# 485             Thorofare Rd  05/29/2021  Sat         4944  Paid       07:00
# 486        Whippoorwill Road  05/28/2021  Fri         4174  Paid       12:00
# 487  Augusta West Kampground  05/28/2021  Fri         4769  Paid       12:00
# 488            East Winthrop  05/28/2021  Fri         4485  Paid       12:00
# 489             Launch Drive  05/28/2021  Fri         4771  Paid       12:00
#
#     END_SHIFT INSPECTIONS TOTALINSP NUMINVASIVE
# 485     17:00         Yes        11
# 486     18:00         Yes        13
# 487     18:00         Yes         1
# 488     18:00         Yes         2
# 489     18:00         Yes        33

# %%
sites_df.drop_duplicates()
# Out:
#                         SITE_NAME        DATE  DAY INSPECTOR_ID  PAID  \
# 0         Augusta West Kampground  08/15/2021  Sun         4769  Paid
# 1                    Launch Drive  08/15/2021  Sun         3796  Paid
# 2             Old Kents Hill Road  08/15/2021  Sun         5006  Paid
# 3                Wilson Pond Road  08/15/2021  Sun         4174  Paid
# 4    Rt 41 North Basin Maranacook  08/15/2021  Sun         5353  Paid
# ..                            ...         ...  ...          ...   ...
# 485                  Thorofare Rd  05/29/2021  Sat         4944  Paid
# 486             Whippoorwill Road  05/28/2021  Fri         4174  Paid
# 487       Augusta West Kampground  05/28/2021  Fri         4769  Paid
# 488                 East Winthrop  05/28/2021  Fri         4485  Paid
# 489                  Launch Drive  05/28/2021  Fri         4771  Paid
#
#     START_SHIFT END_SHIFT INSPECTIONS TOTALINSP NUMINVASIVE
# 0         08:00     18:00         Yes        13
# 1         07:00     17:00         Yes        95
# 2         13:00     19:00         Yes         4
# 3         13:00     19:00         Yes        15
# 4         13:00     19:00         Yes        32
# ..          ...       ...         ...       ...         ...
# 485       07:00     17:00         Yes        11
# 486       12:00     18:00         Yes        13
# 487       12:00     18:00         Yes         1
# 488       12:00     18:00         Yes         2
# 489       12:00     18:00         Yes        33
#
# [490 rows x 10 columns]

# %%
sites_df.to_csv('data/shift_details1.csv', index= False)

# %%
# Followed the same steps as above but selected date range: 8/1/2021 - 7/1/2022 (485 shifts)

time.sleep(7)

num_iterations=500

for _ in range(num_iterations):
    # Your scraping code
    source = driver.page_source
    soup = BeautifulSoup(source, 'html.parser')

    site_name = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='SITE_NAME').find_next('td').text.strip()
    date = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DATE').find_next('td').text.strip()
    day = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DAY').find_next('td').text.strip()
    inspector_id = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTOR_ID').find_next('td').text.strip()
    paid = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='PAY_VOL').find_next('td').text.strip()
    start_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='START_SHIFT').find_next('td').text.strip()
    end_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='END_SHIFT').find_next('td').text.strip()
    inspections = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTIONS').find_next('td').text.strip()
    total_insp = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='TOTALINSP').find_next('td').text.strip()
    numinvasive = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='NUMINVASIVE').find_next('td').text.strip()

    # Create a dictionary
    item = {
        'SITE_NAME': site_name,
        'DATE': date,
        'DAY': day,
        'INSPECTOR_ID': inspector_id,
        'PAID': paid,
        'START_SHIFT': start_shift,
        'END_SHIFT': end_shift,
        'INSPECTIONS': inspections,
        'TOTALINSP': total_insp,
        'NUMINVASIVE': numinvasive
    }

    sites.append(item)
    
    sites_df=pd.DataFrame(sites)
    #print(sites_df.shape)

    # Wait for 3 seconds before the next iteration
    time.sleep(1.5)

sites_df.drop_duplicates()
# Print or process the collected data as needed
print(sites_df.shape)
print('done')
# Out:
# (1591, 10)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[249], line 48
#      46 # Print or process the collected data as needed
#      47 print(sites_df.shape)
# ---> 48 print(done)
#
# NameError: name 'done' is not defined

# %%
sites_df.drop_duplicates().shape
# Out:
# (1323, 10)

# %%
sites_df.drop_duplicates(inplace=True)

# %%
sites_df.tail()
# Out:
#                           SITE_NAME        DATE  DAY INSPECTOR_ID       PAID  \
# 1175  East Winthrop Cobbosseecontee  06/27/2022  Mon         5573       Paid
# 1176   Launch Drive Cobbosseecontee  06/27/2022  Mon         5581       Paid
# 1177  East Winthrop Cobbosseecontee  06/27/2022  Mon         5586       Paid
# 1178   Launch Drive Cobbosseecontee  06/27/2022  Mon         5637  Volunteer
# 1179   Launch Drive Cobbosseecontee  06/27/2022  Mon         5580       Paid
#
#      START_SHIFT END_SHIFT INSPECTIONS TOTALINSP NUMINVASIVE
# 1175       14:00     19:00         Yes         3           0
# 1176       13:00     19:00         Yes         1           0
# 1177       07:00     11:00          No         0           0
# 1178       05:00     09:00         Yes        28           0
# 1179       07:00     11:40         Yes         1           0

# %%
# Ran this just once instead of in for loop for pages of the table that were missed due to timining issues

source = driver.page_source
soup = BeautifulSoup(source, 'html.parser')

site_name = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='SITE_NAME').find_next('td').text.strip()
date = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DATE').find_next('td').text.strip()
day = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DAY').find_next('td').text.strip()
inspector_id = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTOR_ID').find_next('td').text.strip()
paid = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='PAY_VOL').find_next('td').text.strip()
start_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='START_SHIFT').find_next('td').text.strip()
end_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='END_SHIFT').find_next('td').text.strip()
inspections = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTIONS').find_next('td').text.strip()
total_insp = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='TOTALINSP').find_next('td').text.strip()
numinvasive = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='NUMINVASIVE').find_next('td').text.strip()

    # Create a dictionary
item = {
    'SITE_NAME': site_name,
    'DATE': date,
    'DAY': day,
    'INSPECTOR_ID': inspector_id,
    'PAID': paid,
    'START_SHIFT': start_shift,
    'END_SHIFT': end_shift,
    'INSPECTIONS': inspections,
    'TOTALINSP': total_insp,
    'NUMINVASIVE': numinvasive
    }

sites.append(item)

# %%
sites_df=pd.DataFrame(sites)

# %%
sites_df.drop_duplicates(inplace=True)

# %%
sites_df.shape
# Out:
# (1642, 10)

# %%
sites_df.head()
# Out:
#                       SITE_NAME        DATE  DAY INSPECTOR_ID  PAID  \
# 0       Augusta West Kampground  08/15/2021  Sun         4769  Paid
# 1                  Launch Drive  08/15/2021  Sun         3796  Paid
# 2           Old Kents Hill Road  08/15/2021  Sun         5006  Paid
# 3              Wilson Pond Road  08/15/2021  Sun         4174  Paid
# 4  Rt 41 North Basin Maranacook  08/15/2021  Sun         5353  Paid
#
#   START_SHIFT END_SHIFT INSPECTIONS TOTALINSP NUMINVASIVE
# 0       08:00     18:00         Yes        13
# 1       07:00     17:00         Yes        95
# 2       13:00     19:00         Yes         4
# 3       13:00     19:00         Yes        15
# 4       13:00     19:00         Yes        32

# %%
sites_df.reset_index(drop=True, inplace=True)

# %%
sites_df.head()
# Out:
#                       SITE_NAME        DATE  DAY INSPECTOR_ID  PAID  \
# 0       Augusta West Kampground  08/15/2021  Sun         4769  Paid
# 1                  Launch Drive  08/15/2021  Sun         3796  Paid
# 2           Old Kents Hill Road  08/15/2021  Sun         5006  Paid
# 3              Wilson Pond Road  08/15/2021  Sun         4174  Paid
# 4  Rt 41 North Basin Maranacook  08/15/2021  Sun         5353  Paid
#
#   START_SHIFT END_SHIFT INSPECTIONS TOTALINSP NUMINVASIVE
# 0       08:00     18:00         Yes        13
# 1       07:00     17:00         Yes        95
# 2       13:00     19:00         Yes         4
# 3       13:00     19:00         Yes        15
# 4       13:00     19:00         Yes        32

# %%
# if code throws up an error due to the time it took to load a page, check the tail to see where it left off
sites_df.tail()
# Out:
#                             SITE_NAME        DATE  DAY INSPECTOR_ID  \
# 2221  Lakeside Marina Cobbosseecontee  08/27/2022  Sat         5669
# 2222  Lakeside Marina Cobbosseecontee  08/27/2022  Sat         5657
# 2223          Augusta West Kampground  08/27/2022  Sat         4174
# 2224  Lakeside Marina Cobbosseecontee  08/27/2022  Sat         5652
# 2225     Launch Drive Cobbosseecontee  08/27/2022  Sat         5637
#
#            PAID START_SHIFT END_SHIFT INSPECTIONS TOTALINSP NUMINVASIVE
# 2221       Paid       08:45     10:30         Yes         3           0
# 2222       Paid       12:50     12:51         Yes         1           0
# 2223       Paid       08:00     18:00         Yes         8           0
# 2224       Paid       20:08     20:09         Yes         1           0
# 2225  Volunteer       04:58     07:05         Yes        13           0

# %%
# After selecting date range: 7/2/2022 - 8/10/2022 (485 shifts)

time.sleep(7)

num_iterations= 500

print('start')
for _ in range(num_iterations):
    # Your scraping code
    source = driver.page_source
    soup = BeautifulSoup(source, 'html.parser')

    site_name = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='SITE_NAME').find_next('td').text.strip()
    date = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DATE').find_next('td').text.strip()
    day = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DAY').find_next('td').text.strip()
    inspector_id = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTOR_ID').find_next('td').text.strip()
    paid = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='PAY_VOL').find_next('td').text.strip()
    start_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='START_SHIFT').find_next('td').text.strip()
    end_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='END_SHIFT').find_next('td').text.strip()
    inspections = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTIONS').find_next('td').text.strip()
    total_insp = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='TOTALINSP').find_next('td').text.strip()
    numinvasive = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='NUMINVASIVE').find_next('td').text.strip()

    # Create a dictionary
    item = {
        'SITE_NAME': site_name,
        'DATE': date,
        'DAY': day,
        'INSPECTOR_ID': inspector_id,
        'PAID': paid,
        'START_SHIFT': start_shift,
        'END_SHIFT': end_shift,
        'INSPECTIONS': inspections,
        'TOTALINSP': total_insp,
        'NUMINVASIVE': numinvasive
    }

    sites.append(item)
    
    sites_df=pd.DataFrame(sites)
    #print(sites_df.shape)

    # Wait for 3 seconds before the next iteration
    time.sleep(3)

sites_df.drop_duplicates(inplace=True)
# Print or process the collected data as needed
print(sites_df.shape)
print('done')
# Out:
# start
# (2063, 10)
# done

# %%
driver = webdriver.Chrome()
driver.get(url)

# %%
# After selecting date range: 7/28/2022 - 12/31/2022 (485 shifts)

time.sleep(7)

num_iterations= 500

print('start')
for _ in range(num_iterations):
    # Your scraping code
    source = driver.page_source
    soup = BeautifulSoup(source, 'html.parser')

    site_name = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='SITE_NAME').find_next('td').text.strip()
    date = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DATE').find_next('td').text.strip()
    day = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='DAY').find_next('td').text.strip()
    inspector_id = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTOR_ID').find_next('td').text.strip()
    paid = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='PAY_VOL').find_next('td').text.strip()
    start_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='START_SHIFT').find_next('td').text.strip()
    end_shift = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='END_SHIFT').find_next('td').text.strip()
    inspections = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='INSPECTIONS').find_next('td').text.strip()
    total_insp = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='TOTALINSP').find_next('td').text.strip()
    numinvasive = soup.find('th', {'class': 'esri-feature-fields__field-header'}, string='NUMINVASIVE').find_next('td').text.strip()

    # Create a dictionary
    item = {
        'SITE_NAME': site_name,
        'DATE': date,
        'DAY': day,
        'INSPECTOR_ID': inspector_id,
        'PAID': paid,
        'START_SHIFT': start_shift,
        'END_SHIFT': end_shift,
        'INSPECTIONS': inspections,
        'TOTALINSP': total_insp,
        'NUMINVASIVE': numinvasive
    }

    sites.append(item)
    
    sites_df=pd.DataFrame(sites)
    #print(sites_df.shape)

    # Wait for 3 seconds before the next iteration
    time.sleep(3)

sites_df.drop_duplicates(inplace=True)
# Print or process the collected data as needed
print(sites_df.shape)
print('done')
# Out:
# start
# (2586, 10)
# done

# %%
driver = webdriver.Chrome()
driver.get(url)
